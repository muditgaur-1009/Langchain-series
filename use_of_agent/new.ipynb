# %%
import os
from dotenv import load_dotenv

load_dotenv()
LANGCHAIN_TRACING_V2="true"
from langchain_community.tools.tavily_search import TavilySearchResults
search = TavilySearchResults()
search.invoke("what is the weather in SF")
# Out:
# [{'url': 'https://www.weatherapi.com/',
#   'content': "{'location': {'name': 'San Francisco', 'region': 'California', 'country': 'United States of America', 'lat': 37.78, 'lon': -122.42, 'tz_id': 'America/Los_Angeles', 'localtime_epoch': 1724225307, 'localtime': '2024-08-21 00:28'}, 'current': {'last_updated_epoch': 1724224500, 'last_updated': '2024-08-21 00:15', 'temp_c': 18.3, 'temp_f': 64.9, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 260, 'wind_dir': 'W', 'pressure_mb': 1018.0, 'pressure_in': 30.06, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 70, 'cloud': 25, 'feelslike_c': 18.3, 'feelslike_f': 64.9, 'windchill_c': 14.2, 'windchill_f': 57.6, 'heatindex_c': 14.7, 'heatindex_f': 58.5, 'dewpoint_c': 11.5, 'dewpoint_f': 52.7, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 1.0, 'gust_mph': 12.5, 'gust_kph': 20.1}}"},
#  {'url': 'https://www.meteoprog.com/weather/Sanfrancisco/month/august/',
#   'content': 'San Francisco (United States) weather in August 2024 ☀️ Accurate weather forecast for San Francisco in August ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG'},
#  {'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=August',
#   'content': "The average weather in San Francisco in August. The temperatures in San Francisco in August are comfortable with low of 57 ° F and and high up to 77 ° F. There is little to no rain in San Francisco during August, so it's a lot easier to explore the city. Just remember to dress in warm layers, as it can still get pretty chilly."},
#  {'url': 'https://www.weathertab.com/en/c/e/08/united-states/california/san-francisco/',
#   'content': 'Avg Low Temps 50 to 60 °F. Explore comprehensive August 2024 weather forecasts for San Francisco, including daily high and low temperatures, precipitation risks, and monthly temperature trends. Featuring detailed day-by-day forecasts, dynamic graphs of daily rain probabilities, and temperature trends to help you plan ahead.'},
#  {'url': 'https://www.easeweather.com/north-america/united-states/california/city-and-county-of-san-francisco/august',
#   'content': 'The forecast for August 2024 in City and County of San Francisco predicts the temperature to closely align with the historical average at 18.6 ° C 18.6 ° C'}]

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

loader = WebBaseLoader("https://docs.smith.langchain.com/overview")
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
docs = loader.load()
documents = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200
).split_documents(docs)
vector = FAISS.from_documents(documents, embeddings)
retriever = vector.as_retriever()

# %%
from langchain.tools.retriever import create_retriever_tool
retriever_tool = create_retriever_tool(
    retriever,
    "langsmith_search",
    "Search for information about LangSmith. For any questions about LangSmith, you must use this tool!",
)

# %%
tools=[search,retriever_tool]

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-pro",temprature=0.3)

# %%
llm.invoke("hello")
# Out:
# AIMessage(content='Hello there! How can I assist you today?', response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]}, id='run-85a38052-ff3e-4959-b7eb-5b0ec2bafb08-0', usage_metadata={'input_tokens': 2, 'output_tokens': 10, 'total_tokens': 12})

# %%
from langchain import hub

# Get the prompt to use - you can modify this!
prompt = hub.pull("hwchase17/openai-functions-agent")
prompt.messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are a helpful assistant')),
#  MessagesPlaceholder(variable_name='chat_history', optional=True),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')),
#  MessagesPlaceholder(variable_name='agent_scratchpad')]

# %%
from langchain.agents import create_tool_calling_agent

agent = create_tool_calling_agent(llm, tools, prompt)
# Out:
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring

# %%
from langchain.agents import AgentExecutor

agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# %%
agent_executor.invoke({"input": "hi!"})
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# _MultiThreadedRendezvous                  Traceback (most recent call last)
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\grpc_helpers.py:155, in _wrap_stream_errors.<locals>.error_remapped_callable(*args, **kwargs)
#     154     prefetch_first = getattr(callable_, "_prefetch_first_result_", True)
# --> 155     return _StreamingResponseIterator(
#     156         result, prefetch_first_result=prefetch_first
#     157     )
#     158 except grpc.RpcError as exc:
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\grpc_helpers.py:81, in _StreamingResponseIterator.__init__(self, wrapped, prefetch_first_result)
#      80     if prefetch_first_result:
# ---> 81         self._stored_first_result = next(self._wrapped)
#      82 except TypeError:
#      83     # It is possible the wrapped method isn't an iterable (a grpc.Call
#      84     # for instance). If this happens don't store the first result.
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\grpc\_channel.py:542, in _Rendezvous.__next__(self)
#     541 def __next__(self):
# --> 542     return self._next()
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\grpc\_channel.py:968, in _MultiThreadedRendezvous._next(self)
#     967 elif self._state.code is not None:
# --> 968     raise self
#
# _MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Developer instruction is not enabled for models/gemini-pro"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:172.217.160.170:443 {grpc_message:"Developer instruction is not enabled for models/gemini-pro", grpc_status:3, created_time:"2024-08-21T09:36:10.0394978+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:176, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     175 try:
# --> 176     return generation_method(**kwargs)
#     177 # Do not retry for these errors.
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1122, in GenerativeServiceClient.stream_generate_content(self, request, model, contents, retry, timeout, metadata)
#    1121 # Send the request.
# -> 1122 response = rpc(
#    1123     request,
#    1124     retry=retry,
#    1125     timeout=timeout,
#    1126     metadata=metadata,
#    1127 )
#    1129 # Done; return the response.
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\gapic_v1\method.py:113, in _GapicCallable.__call__(self, timeout, retry, *args, **kwargs)
#     111     kwargs["metadata"] = metadata
# --> 113 return wrapped_func(*args, **kwargs)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     190 try:
# --> 191     return target()
#     193 # pylint: disable=broad-except
#     194 # This function explicitly must deal with broad exceptions.
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\grpc_helpers.py:159, in _wrap_stream_errors.<locals>.error_remapped_callable(*args, **kwargs)
#     158 except grpc.RpcError as exc:
# --> 159     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 Developer instruction is not enabled for models/gemini-pro
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 agent_executor.invoke({"input": "hi!"})
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\agents\agent.py:1608, in AgentExecutor._call(self, inputs, run_manager)
#    1606 # We now enter the agent loop (until it returns something).
#    1607 while self._should_continue(iterations, time_elapsed):
# -> 1608     next_step_output = self._take_next_step(
#    1609         name_to_tool_map,
#    1610         color_mapping,
#    1611         inputs,
#    1612         intermediate_steps,
#    1613         run_manager=run_manager,
#    1614     )
#    1615     if isinstance(next_step_output, AgentFinish):
#    1616         return self._return(
#    1617             next_step_output, intermediate_steps, run_manager=run_manager
#    1618         )
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\agents\agent.py:1314, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1305 def _take_next_step(
#    1306     self,
#    1307     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1311     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1312 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1313     return self._consume_next_step(
# -> 1314         [
#    1315             a
#    1316             for a in self._iter_next_step(
#    1317                 name_to_tool_map,
#    1318                 color_mapping,
#    1319                 inputs,
#    1320                 intermediate_steps,
#    1321                 run_manager,
#    1322             )
#    1323         ]
#    1324     )
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\agents\agent.py:1314, in <listcomp>(.0)
#    1305 def _take_next_step(
#    1306     self,
#    1307     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1311     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1312 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1313     return self._consume_next_step(
# -> 1314         [
#    1315             a
#    1316             for a in self._iter_next_step(
#    1317                 name_to_tool_map,
#    1318                 color_mapping,
#    1319                 inputs,
#    1320                 intermediate_steps,
#    1321                 run_manager,
#    1322             )
#    1323         ]
#    1324     )
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\agents\agent.py:1342, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1339     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1341     # Call the LLM to see what to do.
# -> 1342     output = self.agent.plan(
#    1343         intermediate_steps,
#    1344         callbacks=run_manager.get_child() if run_manager else None,
#    1345         **inputs,
#    1346     )
#    1347 except OutputParserException as e:
#    1348     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\agents\agent.py:576, in RunnableMultiActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     568 final_output: Any = None
#     569 if self.stream_runnable:
#     570     # Use streaming to make sure that the underlying LLM is invoked in a
#     571     # streaming
#    (...)
#     574     # Because the response from the plan is not a generator, we need to
#     575     # accumulate the output into final output and return that.
# --> 576     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     577         if final_output is None:
#     578             final_output = chunk
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3262, in RunnableSequence.stream(self, input, config, **kwargs)
#    3256 def stream(
#    3257     self,
#    3258     input: Input,
#    3259     config: Optional[RunnableConfig] = None,
#    3260     **kwargs: Optional[Any],
#    3261 ) -> Iterator[Output]:
# -> 3262     yield from self.transform(iter([input]), config, **kwargs)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3249, in RunnableSequence.transform(self, input, config, **kwargs)
#    3243 def transform(
#    3244     self,
#    3245     input: Iterator[Input],
#    3246     config: Optional[RunnableConfig] = None,
#    3247     **kwargs: Optional[Any],
#    3248 ) -> Iterator[Output]:
# -> 3249     yield from self._transform_stream_with_config(
#    3250         input,
#    3251         self._transform,
#    3252         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3253         **kwargs,
#    3254     )
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:2054, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2052 try:
#    2053     while True:
# -> 2054         chunk: Output = context.run(next, iterator)  # type: ignore
#    2055         yield chunk
#    2056         if final_output_supported:
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3211, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3208     else:
#    3209         final_pipeline = step.transform(final_pipeline, config)
# -> 3211 for output in final_pipeline:
#    3212     yield output
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:1272, in Runnable.transform(self, input, config, **kwargs)
#    1269 final: Input
#    1270 got_first_val = False
# -> 1272 for ichunk in input:
#    1273     # The default implementation of transform is to buffer input and
#    1274     # then call stream.
#    1275     # It'll attempt to gather all input into a single chunk using
#    1276     # the `+` operator.
#    1277     # If the input is not addable, then we'll assume that we can
#    1278     # only operate on the last chunk,
#    1279     # and we'll iterate until we get to the last chunk.
#    1280     if not got_first_val:
#    1281         final = ichunk
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:5301, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5295 def transform(
#    5296     self,
#    5297     input: Iterator[Input],
#    5298     config: Optional[RunnableConfig] = None,
#    5299     **kwargs: Any,
#    5300 ) -> Iterator[Output]:
# -> 5301     yield from self.bound.transform(
#    5302         input,
#    5303         self._merge_configs(config),
#    5304         **{**self.kwargs, **kwargs},
#    5305     )
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:410, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     403 except BaseException as e:
#     404     run_manager.on_llm_error(
#     405         e,
#     406         response=LLMResult(
#     407             generations=[[generation]] if generation else []
#     408         ),
#     409     )
# --> 410     raise e
#     411 else:
#     412     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:390, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     387     self.rate_limiter.acquire(blocking=True)
#     389 try:
# --> 390     for chunk in self._stream(messages, stop=stop, **kwargs):
#     391         if chunk.message.id is None:
#     392             chunk.message.id = f"run-{run_manager.run_id}"
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:1019, in ChatGoogleGenerativeAI._stream(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, **kwargs)
#     997 def _stream(
#     998     self,
#     999     messages: List[BaseMessage],
#    (...)
#    1008     **kwargs: Any,
#    1009 ) -> Iterator[ChatGenerationChunk]:
#    1010     request = self._prepare_request(
#    1011         messages,
#    1012         stop=stop,
#    (...)
#    1017         generation_config=generation_config,
#    1018     )
# -> 1019     response: GenerateContentResponse = _chat_with_retry(
#    1020         request=request,
#    1021         generation_method=self.client.stream_generate_content,
#    1022         **kwargs,
#    1023         metadata=self.default_metadata,
#    1024     )
#    1025     for chunk in response:
#    1026         _chat_result = _response_to_result(chunk, stream=True)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:194, in _chat_with_retry(generation_method, **kwargs)
#     191     except Exception as e:
#     192         raise e
# --> 194 return _chat_with_retry(**kwargs)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\mudit\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_genai\chat_models.py:188, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     185         raise ValueError(error_msg)
#     187 except google.api_core.exceptions.InvalidArgument as e:
# --> 188     raise ChatGoogleGenerativeAIError(
#     189         f"Invalid argument provided to Gemini: {e}"
#     190     ) from e
#     191 except Exception as e:
#     192     raise e
#
# ChatGoogleGenerativeAIError: Invalid argument provided to Gemini: 400 Developer instruction is not enabled for models/gemini-pro
